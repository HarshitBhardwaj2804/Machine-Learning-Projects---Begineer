# %% [markdown]
# ## A simple machine learning project, leverage's the logistic regresion algorithm to classifies mines and rocks using sonar data.

# %%
## Importing dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
## Importing  Sonar Dataset
df = pd.read_csv("sonar.csv", header = None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
df.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
## spliting the dataset in training and testing
X = df.drop(columns = 60, axis = 1)
y = df[60]

# %%
X.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      50      51      52      53      54      55      56  \
# 0  0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
#
#        57      58      59
# 0  0.0084  0.0090  0.0032
# 1  0.0049  0.0052  0.0044
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Model Creation

# %%
# Using SVM
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
y_pred_1 = svc.predict(X_test)

# %%
## Getting accuracy
from sklearn.metrics import accuracy_score, classification_report
score_1 = accuracy_score(y_test, y_pred_1)
report_1 = classification_report(y_test, y_pred_1)
print(score_1*100)
print(report_1)
# Out:
# 82.53968253968253
#               precision    recall  f1-score   support
#
#            M       0.82      0.89      0.85        35
#            R       0.84      0.75      0.79        28
#
#     accuracy                           0.83        63
#    macro avg       0.83      0.82      0.82        63
# weighted avg       0.83      0.83      0.82        63

# %%
## checking for multicolinearrity
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                col_name = corr_matrix.columns[i]
                col_corr.add(col_name)
    return col_corr

correlation(X_train, 0.90)
# Out:
# {np.int64(15), np.int64(17), np.int64(20)}

# %%
X_train_updated = X_train.drop([15, 17, 20], axis = 1)
X_test_updated = X_test.drop([15, 17, 20], axis = 1)

# %%
svc_1 = SVC()
svc_1.fit(X_train_updated, y_train)
y_pred_2 = svc_1.predict(X_test_updated)

# %%
## Getting accuracy
from sklearn.metrics import accuracy_score, classification_report
score_2 = accuracy_score(y_test, y_pred_2)
report_2 = classification_report(y_test, y_pred_2)
print(score_2*100)
print(report_2)
# Out:
# 84.12698412698413
#               precision    recall  f1-score   support
#
#            M       0.82      0.91      0.86        35
#            R       0.88      0.75      0.81        28
#
#     accuracy                           0.84        63
#    macro avg       0.85      0.83      0.84        63
# weighted avg       0.84      0.84      0.84        63

# %% [markdown]
# ## Observations:
# 1. We get a accuracy of 82.53% when we use the svc model before multicolinearrity
# 2. We get a accuracy of 84.12% after applying multicolinearity

# %% [markdown]
# ## HyperParameter tunning using GridSearchCV

# %%
param_dict = {
    "C" : [1, 10, 100],
    "kernel" : ['linear', 'poly', 'rbf', 'sigmoid']
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(svc_1, param_grid = param_dict, scoring = 'accuracy', cv = 5)

# %%
grid.fit(X_train_updated, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 10, 100],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
grid.best_score_
# Out:
# np.float64(0.8068965517241379)

# %%
y_pred_3 = grid.predict(X_test_updated)

# %%
## Getting accuracy
from sklearn.metrics import accuracy_score, classification_report
score_3 = accuracy_score(y_test, y_pred_3)
report_3 = classification_report(y_test, y_pred_3)
print(score_3*100)
print(report_3)
# Out:
# 90.47619047619048
#               precision    recall  f1-score   support
#
#            M       0.87      0.97      0.92        35
#            R       0.96      0.82      0.88        28
#
#     accuracy                           0.90        63
#    macro avg       0.92      0.90      0.90        63
# weighted avg       0.91      0.90      0.90        63

# %% [markdown]
# ## Observastion:
# With hyperparameter tunning we get a accuracy of 90.47%

# %% [markdown]
# ## Using the logistic regerssion model

# %%
from sklearn.linear_model import LogisticRegression
reg_1 = LogisticRegression()
reg_1.fit(X_train_updated, y_train)
y_pred_r1 = reg_1.predict(X_test_updated)

# %%
## Getting accuracy
from sklearn.metrics import accuracy_score, classification_report
score_r1 = accuracy_score(y_test, y_pred_r1)
report_r1 = classification_report(y_test, y_pred_r1)
print(score_r1*100)
print(report_r1)
# Out:
# 80.95238095238095
#               precision    recall  f1-score   support
#
#            M       0.81      0.86      0.83        35
#            R       0.81      0.75      0.78        28
#
#     accuracy                           0.81        63
#    macro avg       0.81      0.80      0.81        63
# weighted avg       0.81      0.81      0.81        63

# %% [markdown]
# ## Hyperparameter tunning the Logistic model using gridsearchcv

# %%
logistic_param_dict = {
    'penalty' : ['l1', 'l2'],
    'C' : [0.01, 0.1, 1, 10, 100],
    'solver' : ['newton-cg', 'lbfgs', 'liblinear']
}

# %%
from sklearn.model_selection import GridSearchCV
grid_1 = GridSearchCV(reg_1, param_grid = logistic_param_dict, scoring = 'accuracy', cv = 5)

# %%
grid_1.fit(X_train_updated, y_train)
y_pred_r2 = grid_1.predict(X_test_updated)
# Out:
# C:\Users\Harshit\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Harshit\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 50 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# ...

# %%
## Getting accuracy
from sklearn.metrics import accuracy_score, classification_report
score_r2 = accuracy_score(y_test, y_pred_r2)
report_r2 = classification_report(y_test, y_pred_r2)
print(score_r2*100)
print(report_r2)
# Out:
# 82.53968253968253
#               precision    recall  f1-score   support
#
#            M       0.85      0.83      0.84        35
#            R       0.79      0.82      0.81        28
#
#     accuracy                           0.83        63
#    macro avg       0.82      0.82      0.82        63
# weighted avg       0.83      0.83      0.83        63

# %%
## Testing for new data
import numpy as np

# Example user input (should be 60 values)
input_data = (0.0201,0.0178,0.0274,0.0232,0.0724,0.0833,0.1232,0.1298,0.2085,0.2720,0.2188,0.3037,0.2959,0.2059,0.0906,0.1610,0.1800,0.2180,0.2026,0.1506,0.0521,0.2143,0.4333,0.5943,0.6926,0.7576,0.8787,0.9060,0.8528,0.9087,0.9657,0.9306,0.7774,0.6643,0.6604,0.6884,0.6938,0.5932,0.5774,0.6223,0.5841,0.4527,0.4911,0.5762,0.5013,0.4042,0.3123,0.2232,0.1085,0.0414,0.0253,0.0131,0.0049,0.0104,0.0102,0.0092,0.0083,0.0020,0.0048,0.0036)  
# Convert to numpy array
input_arr = np.asarray(input_data)

# Remove columns 15, 17, and 20 (note: after removing one, indices shift)
indices_to_remove = [15, 17, 20]

# Sort in descending order to avoid shifting issues while deleting
for index in sorted(indices_to_remove, reverse=True):
    input_arr = np.delete(input_arr, index)

# Reshape to match model input
input_data_reshape = input_arr.reshape(1, -1)

# Now you can pass it to your model
prediction = grid.predict(input_data_reshape)
print(prediction)
# Out:
# ['M']

# %% [markdown]
# ## Using KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train_updated, y_train)
y_pred_k1 = knn.predict(X_test_updated)

# %%
## Getting accuracy
from sklearn.metrics import accuracy_score, classification_report
score_k1 = accuracy_score(y_test, y_pred_k1)
report_k1 = classification_report(y_test, y_pred_k1)
print(score_k1*100)
print(report_k1)
# Out:
# 85.71428571428571
#               precision    recall  f1-score   support
#
#            M       0.88      0.86      0.87        35
#            R       0.83      0.86      0.84        28
#
#     accuracy                           0.86        63
#    macro avg       0.85      0.86      0.86        63
# weighted avg       0.86      0.86      0.86        63

# %% [markdown]
# ## HyperParameter tunning of KNN using GridSearchCV

# %%
knn_param_dict = {
    'n_neighbors' : [4,5,6,7,8],
    'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'p' : [1,2]
}

# %%
knn = KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV
grid_knn = GridSearchCV(knn, param_grid=knn_param_dict, scoring='accuracy', cv = 5)

# %%
grid_knn.fit(X_train_updated, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [4, 5, 6, 7, 8], 'p': [1, 2]},
#              scoring='accuracy')

# %%
grid_knn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'p': 1}

# %%
grid_knn.best_score_
# Out:
# np.float64(0.7310344827586206)

# %%
y_pred_k2 = grid_knn.predict(X_test_updated)

# %%
## Getting accuracy
from sklearn.metrics import accuracy_score, classification_report
score_k2 = accuracy_score(y_test, y_pred_k2)
report_k2 = classification_report(y_test, y_pred_k2)
print(score_k2*100)
print(report_k2)
# Out:
# 90.47619047619048
#               precision    recall  f1-score   support
#
#            M       0.94      0.89      0.91        35
#            R       0.87      0.93      0.90        28
#
#     accuracy                           0.90        63
#    macro avg       0.90      0.91      0.90        63
# weighted avg       0.91      0.90      0.91        63

# %%
## Testing for new data
import numpy as np

# Example user input (should be 60 values)
input_data = (0.0201,0.0178,0.0274,0.0232,0.0724,0.0833,0.1232,0.1298,0.2085,0.2720,0.2188,0.3037,0.2959,0.2059,0.0906,0.1610,0.1800,0.2180,0.2026,0.1506,0.0521,0.2143,0.4333,0.5943,0.6926,0.7576,0.8787,0.9060,0.8528,0.9087,0.9657,0.9306,0.7774,0.6643,0.6604,0.6884,0.6938,0.5932,0.5774,0.6223,0.5841,0.4527,0.4911,0.5762,0.5013,0.4042,0.3123,0.2232,0.1085,0.0414,0.0253,0.0131,0.0049,0.0104,0.0102,0.0092,0.0083,0.0020,0.0048,0.0036)  
# Convert to numpy array
input_arr = np.asarray(input_data)

# Remove columns 15, 17, and 20 (note: after removing one, indices shift)
indices_to_remove = [15, 17, 20]

# Sort in descending order to avoid shifting issues while deleting
for index in sorted(indices_to_remove, reverse=True):
    input_arr = np.delete(input_arr, index)

# Reshape to match model input
input_data_reshape = input_arr.reshape(1, -1)

# Now you can pass it to your model
prediction = grid_knn.predict(input_data_reshape)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 20
#      17 input_data_reshape = input_arr.reshape(1, -1)
#      19 # Now you can pass it to your model
# ---> 20 prediction = grid_knn.predict(input_data_reshape)
#      21 print(prediction)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:598, in BaseSearchCV.predict(self, X)
#     580 """Call predict on the estimator with the best found parameters.
#     581
#     582 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     595     the best found parameters.
#     596 """
#     597 check_is_fitted(self)
# --> 598 return self.best_estimator_.predict(X)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neighbors\_classification.py:262, in KNeighborsClassifier.predict(self, X)
# ...
